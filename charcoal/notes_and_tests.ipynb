# %% [markdown]
# # Notes and Tests
#
# This is a jupyter notebook where different techniques and tests are performed in a REPL form.
#
# ### Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image
#import requests
from zipfile import ZipFile

# %% [markdown]
# ### Opening image files

# %%
# ----------------------------
# Declares anonymous functions
# ----------------------------

retrieve_tif = lambda x: x[-4:]==".tif"
retrieve_tiff = lambda x: x[-5:]==".tiff"

# --------------------------
# Declares generic functions
# --------------------------

def check_create_folder(path: str) -> None:
    """
    Checks if a folder path exists and creates
    it if it does not.
    
    Parameters
    ----------
    path : String
        Path of the folder to check
    """
    if not os.path.exists(path):
        os.makedirs(path)
        print(f"{path} created")

def plot_PIL_image(img: Image) -> None:
    """
    Plots a .tiff PIL image.
    
    Parameters
    ----------
    img : PIL.TiffImagePlugin.TiffImageFile
    An .tiff PIL Image object (tested on .tiff)
    
    Returns
    -------
    None
    """
    plt.figure(figsize=(8,6))
    plt.imshow(np.asarray(img, dtype = np.uint8), cmap="gray")
    plt.title(image_files[0])
    plt.show()
    
if __name__ == "__main__":
    # declares the target path for downloading the
    # Charcoal dataset as .zip from the source website
    ufpr_dataset_path = "./dataset_ufpr"

# %%
check_create_folder("dataset_ufpr")
# Out:
# dataset_ufpr created

# %%
# Declares variables and anonymous functions
ufpr_dataset_path = "../dataset_ufpr/" # Expected to be run from the test folder

# Retrieves .tif images
image_files = list(filter(retrieve_tif, sorted(os.listdir(ufpr_dataset_path))))

# Renames images from .tif to .tiff

for f in image_files:
    old_name = f"{upfr_dataset_path}{f}"
    new_name = f"{upfr_dataset_path}{f}f"
    #os.rename(old_name, new_name)
    
# Retrieves .tiff images
image_files = list(filter(retrieve_tiff, sorted(os.listdir(ufpr_dataset_path))))

# %%
x = ufpr_dataset_path+image_files[0]
x.split("//")[-1]
# Out:
# '../dataset_ufpr/Apuleia molaris 1.tiff'

# %%
crop_dimensions = (0,0,1280,960)
with Image.open(ufpr_dataset_path+image_files[0]) as img:
    # Crops image
    img = img.crop(crop_dimensions)
    img.save("test.tiff")

# %% [raw]
# l,t,r,b = [0,0,1280,960]
#
#     structure = list(os.walk(destination))[1:]
#
#     for label in structure:
#         for image in label[2]:
#             path = label[0] + '/' + image
#             print(path)
#             # path.split('.')[0]
#             img = Image.open(path)
#             img = img.crop((l,t,r,b))
#             img = np.asarray(img, dtype = np.uint8)
#             # I am cropping out the bottom part with words and numbers
#             img = img[...,np.newaxis]
#             dat = np.concatenate((img[:,:1280,:],
#                                   img[:,1280:,:],
#                                   np.zeros(shape = (960, 1280,1), dtype = np.uint8)), axis = 2)
#             new_img = Image.fromarray(dat, 'RGB')
#             new_img.save(fp = path)

# %%
url = "http://www.inf.ufpr.br/vri/databases/florestais/charcoal.zip"
myfile = request.get(url)
open(ufpr_dataset_path+"charcoal.zip").write(myfile.content)

# %%
filename = "charcoal.zip"
with ZipFile(filename, "r") as zip:
    print(f"Extracting all files contained in {filename}")
    zip.extractall()
    print("Done")

# %%
help(ZipFile.extractall)
# Out:
# Help on function extractall in module zipfile:
#
# extractall(self, path=None, members=None, pwd=None)
#     Extract all members from the archive to the current working
#     directory. `path' specifies a different directory to extract to.
#     `members' is optional and must be a subset of the list returned
#     by namelist().

# %%
f = lambda x: (x, 
               "_".join(x.split(" ")[:2]))
list(map(f, image_files))
# Out:
# [('Apuleia molaris 1.tiff', 'Apuleia_molaris', '1.tiff'),
#  ('Apuleia molaris 10.tiff', 'Apuleia_molaris', '10.tiff'),
#  ('Apuleia molaris 11.tiff', 'Apuleia_molaris', '11.tiff'),
#  ('Apuleia molaris 12.tiff', 'Apuleia_molaris', '12.tiff'),
#  ('Apuleia molaris 2.tiff', 'Apuleia_molaris', '2.tiff'),
#  ('Apuleia molaris 3.tiff', 'Apuleia_molaris', '3.tiff'),
#  ('Apuleia molaris 4.tiff', 'Apuleia_molaris', '4.tiff'),
#  ('Apuleia molaris 5.tiff', 'Apuleia_molaris', '5.tiff'),
#  ('Apuleia molaris 6.tiff', 'Apuleia_molaris', '6.tiff'),
#  ('Apuleia molaris 7.tiff', 'Apuleia_molaris', '7.tiff'),
#  ('Apuleia molaris 8.tiff', 'Apuleia_molaris', '8.tiff'),
#  ('Apuleia molaris 9.tiff', 'Apuleia_molaris', '9.tiff'),
#  ('Aspidosperma populifolium 1.tiff', 'Aspidosperma_populifolium', '1.tiff'),
#  ('Aspidosperma populifolium 10.tiff', 'Aspidosperma_populifolium', '10.tiff'),
#  ('Aspidosperma populifolium 11.tiff', 'Aspidosperma_populifolium', '11.tiff'),
#  ('Aspidosperma populifolium 12.tiff', 'Aspidosperma_populifolium', '12.tiff'),
#  ('Aspidosperma populifolium 2.tiff', 'Aspidosperma_populifolium', '2.tiff'),
#  ('Aspidosperma populifolium 3.tiff', 'Aspidosperma_populifolium', '3.tiff'),
#  ('Aspidosperma populifolium 4.tiff', 'Aspidosperma_populifolium', '4.tiff'),
#  ('Aspidosperma populifolium 5.tiff', 'Aspidosperma_populifolium', '5.tiff'),
#  ('Aspidosperma populifolium 6.tiff', 'Aspidosperma_populifolium', '6.tiff'),
#  ('Aspidosperma populifolium 7.tiff', 'Aspidosperma_populifolium', '7.tiff'),
#  ('Aspidosperma populifolium 8.tiff', 'Aspidosperma_populifolium', '8.tiff'),
#  ('Aspidosperma populifolium 9.tiff', 'Aspidosperma_populifolium', '9.tiff'),
#  ('Astronium gracile 1.tiff', 'Astronium_gracile', '1.tiff'),
#  ('Astronium gracile 10.tiff', 'Astronium_gracile', '10.tiff'),
#  ('Astronium gracile 11.tiff', 'Astronium_gracile', '11.tiff'),
#  ('Astronium gracile 12.tiff', 'Astronium_gracile', '12.tiff'),
#  ('Astronium gracile 2.tiff', 'Astronium_gracile', '2.tiff'),
#  ('Astronium gracile 3.tiff', 'Astronium_gracile', '3.tiff'),
#  ('Astronium gracile 4.tiff', 'Astronium_gracile', '4.tiff'),
#  ('Astronium gracile 5.tiff', 'Astronium_gracile', '5.tiff'),
#  ('Astronium gracile 6.tiff', 'Astronium_gracile', '6.tiff'),
#  ('Astronium gracile 7.tiff', 'Astronium_gracile', '7.tiff'),
#  ('Astronium gracile 8.tiff', 'Astronium_gracile', '8.tiff'),
#  ('Astronium gracile 9.tiff', 'Astronium_gracile', '9.tiff'),
#  ('Byrsonima coriaceae 1.tiff', 'Byrsonima_coriaceae', '1.tiff'),
#  ('Byrsonima coriaceae 10.tiff', 'Byrsonima_coriaceae', '10.tiff'),
#  ('Byrsonima coriaceae 11.tiff', 'Byrsonima_coriaceae', '11.tiff'),
#  ('Byrsonima coriaceae 12.tiff', 'Byrsonima_coriaceae', '12.tiff'),
#  ('Byrsonima coriaceae 2.tiff', 'Byrsonima_coriaceae', '2.tiff'),
#  ('Byrsonima coriaceae 3.tiff', 'Byrsonima_coriaceae', '3.tiff'),
#  ('Byrsonima coriaceae 4.tiff', 'Byrsonima_coriaceae', '4.tiff'),
#  ('Byrsonima coriaceae 5.tiff', 'Byrsonima_coriaceae', '5.tiff'),
#  ('Byrsonima coriaceae 6.tiff', 'Byrsonima_coriaceae', '6.tiff'),
#  ('Byrsonima coriaceae 7.tiff', 'Byrsonima_coriaceae', '7.tiff'),
#  ('Byrsonima coriaceae 8.tiff', 'Byrsonima_coriaceae', '8.tiff'),
#  ('Byrsonima coriaceae 9.tiff', 'Byrsonima_coriaceae', '9.tiff'),
#  ('Calophyllum brasiliensis 1.tiff', 'Calophyllum_brasiliensis', '1.tiff'),
#  ('Calophyllum brasiliensis 10.tiff', 'Calophyllum_brasiliensis', '10.tiff'),
#  ('Calophyllum brasiliensis 11.tiff', 'Calophyllum_brasiliensis', '11.tiff'),
#  ('Calophyllum brasiliensis 12.tiff', 'Calophyllum_brasiliensis', '12.tiff'),
#  ('Calophyllum brasiliensis 2.tiff', 'Calophyllum_brasiliensis', '2.tiff'),
#  ('Calophyllum brasiliensis 3.tiff', 'Calophyllum_brasiliensis', '3.tiff'),
#  ('Calophyllum brasiliensis 4.tiff', 'Calophyllum_brasiliensis', '4.tiff'),
#  ('Calophyllum brasiliensis 5.tiff', 'Calophyllum_brasiliensis', '5.tiff'),
#  ('Calophyllum brasiliensis 6.tiff', 'Calophyllum_brasiliensis', '6.tiff'),
#  ('Calophyllum brasiliensis 7.tiff', 'Calophyllum_brasiliensis', '7.tiff'),
#  ('Calophyllum brasiliensis 8.tiff', 'Calophyllum_brasiliensis', '8.tiff'),
#  ('Calophyllum brasiliensis 9.tiff', 'Calophyllum_brasiliensis', '9.tiff'),
#  ('Cecropia glaziovii 1.tiff', 'Cecropia_glaziovii', '1.tiff'),
#  ('Cecropia glaziovii 10.tiff', 'Cecropia_glaziovii', '10.tiff'),
#  ('Cecropia glaziovii 11.tiff', 'Cecropia_glaziovii', '11.tiff'),
#  ('Cecropia glaziovii 12.tiff', 'Cecropia_glaziovii', '12.tiff'),
#  ('Cecropia glaziovii 2.tiff', 'Cecropia_glaziovii', '2.tiff'),
#  ('Cecropia glaziovii 3.tiff', 'Cecropia_glaziovii', '3.tiff'),
#  ('Cecropia glaziovii 4.tiff', 'Cecropia_glaziovii', '4.tiff'),
#  ('Cecropia glaziovii 5.tiff', 'Cecropia_glaziovii', '5.tiff'),
#  ('Cecropia glaziovii 6.tiff', 'Cecropia_glaziovii', '6.tiff'),
#  ('Cecropia glaziovii 7.tiff', 'Cecropia_glaziovii', '7.tiff'),
#  ('Cecropia glaziovii 8.tiff', 'Cecropia_glaziovii', '8.tiff'),
#  ('Cecropia glaziovii 9.tiff', 'Cecropia_glaziovii', '9.tiff'),
#  ('Cecropia sciadophylla 1.tiff', 'Cecropia_sciadophylla', '1.tiff'),
#  ('Cecropia sciadophylla 10.tiff', 'Cecropia_sciadophylla', '10.tiff'),
#  ('Cecropia sciadophylla 11.tiff', 'Cecropia_sciadophylla', '11.tiff'),
#  ('Cecropia sciadophylla 12.tiff', 'Cecropia_sciadophylla', '12.tiff'),
#  ('Cecropia sciadophylla 2.tiff', 'Cecropia_sciadophylla', '2.tiff'),
#  ('Cecropia sciadophylla 3.tiff', 'Cecropia_sciadophylla', '3.tiff'),
#  ('Cecropia sciadophylla 4.tiff', 'Cecropia_sciadophylla', '4.tiff'),
#  ('Cecropia sciadophylla 5.tiff', 'Cecropia_sciadophylla', '5.tiff'),
#  ('Cecropia sciadophylla 6.tiff', 'Cecropia_sciadophylla', '6.tiff'),
#  ('Cecropia sciadophylla 7.tiff', 'Cecropia_sciadophylla', '7.tiff'),
#  ('Cecropia sciadophylla 8.tiff', 'Cecropia_sciadophylla', '8.tiff'),
#  ('Cecropia sciadophylla 9.tiff', 'Cecropia_sciadophylla', '9.tiff'),
#  ('Cedrelinga catenaeformis 1.tiff', 'Cedrelinga_catenaeformis', '1.tiff'),
#  ('Cedrelinga catenaeformis 10.tiff', 'Cedrelinga_catenaeformis', '10.tiff'),
#  ('Cedrelinga catenaeformis 11.tiff', 'Cedrelinga_catenaeformis', '11.tiff'),
#  ('Cedrelinga catenaeformis 12.tiff', 'Cedrelinga_catenaeformis', '12.tiff'),
#  ('Cedrelinga catenaeformis 2.tiff', 'Cedrelinga_catenaeformis', '2.tiff'),
#  ('Cedrelinga catenaeformis 3.tiff', 'Cedrelinga_catenaeformis', '3.tiff'),
#  ('Cedrelinga catenaeformis 4.tiff', 'Cedrelinga_catenaeformis', '4.tiff'),
#  ('Cedrelinga catenaeformis 5.tiff', 'Cedrelinga_catenaeformis', '5.tiff'),
#  ('Cedrelinga catenaeformis 6.tiff', 'Cedrelinga_catenaeformis', '6.tiff'),
#  ('Cedrelinga catenaeformis 7.tiff', 'Cedrelinga_catenaeformis', '7.tiff'),
#  ('Cedrelinga catenaeformis 8.tiff', 'Cedrelinga_catenaeformis', '8.tiff'),
#  ('Cedrelinga catenaeformis 9.tiff', 'Cedrelinga_catenaeformis', '9.tiff'),
#  ('Cochlospermum orinoccense 1.tiff', 'Cochlospermum_orinoccense', '1.tiff'),
#  ('Cochlospermum orinoccense 10.tiff', 'Cochlospermum_orinoccense', '10.tiff'),
#  ('Cochlospermum orinoccense 11.tiff', 'Cochlospermum_orinoccense', '11.tiff'),
#  ('Cochlospermum orinoccense 12.tiff', 'Cochlospermum_orinoccense', '12.tiff'),
#  ('Cochlospermum orinoccense 2.tiff', 'Cochlospermum_orinoccense', '2.tiff'),
#  ('Cochlospermum orinoccense 3.tiff', 'Cochlospermum_orinoccense', '3.tiff'),
#  ('Cochlospermum orinoccense 4.tiff', 'Cochlospermum_orinoccense', '4.tiff'),
#  ('Cochlospermum orinoccense 5.tiff', 'Cochlospermum_orinoccense', '5.tiff'),
#  ('Cochlospermum orinoccense 6.tiff', 'Cochlospermum_orinoccense', '6.tiff'),
#  ('Cochlospermum orinoccense 7.tiff', 'Cochlospermum_orinoccense', '7.tiff'),
#  ('Cochlospermum orinoccense 8.tiff', 'Cochlospermum_orinoccense', '8.tiff'),
#  ('Cochlospermum orinoccense 9.tiff', 'Cochlospermum_orinoccense', '9.tiff'),
#  ('Combretum leprosum 1.tiff', 'Combretum_leprosum', '1.tiff'),
#  ('Combretum leprosum 10.tiff', 'Combretum_leprosum', '10.tiff'),
#  ('Combretum leprosum 11.tiff', 'Combretum_leprosum', '11.tiff'),
#  ('Combretum leprosum 12.tiff', 'Combretum_leprosum', '12.tiff'),
#  ('Combretum leprosum 2.tiff', 'Combretum_leprosum', '2.tiff'),
#  ('Combretum leprosum 3.tiff', 'Combretum_leprosum', '3.tiff'),
#  ('Combretum leprosum 4.tiff', 'Combretum_leprosum', '4.tiff'),
#  ('Combretum leprosum 5.tiff', 'Combretum_leprosum', '5.tiff'),
#  ('Combretum leprosum 6.tiff', 'Combretum_leprosum', '6.tiff'),
#  ('Combretum leprosum 7.tiff', 'Combretum_leprosum', '7.tiff'),
#  ('Combretum leprosum 8.tiff', 'Combretum_leprosum', '8.tiff'),
#  ('Combretum leprosum 9.tiff', 'Combretum_leprosum', '9.tiff'),
#  ('Copaifera langsdorfii 1.tiff', 'Copaifera_langsdorfii', '1.tiff'),
#  ('Copaifera langsdorfii 10.tiff', 'Copaifera_langsdorfii', '10.tiff'),
#  ('Copaifera langsdorfii 11.tiff', 'Copaifera_langsdorfii', '11.tiff'),
#  ('Copaifera langsdorfii 12.tiff', 'Copaifera_langsdorfii', '12.tiff'),
#  ('Copaifera langsdorfii 2.tiff', 'Copaifera_langsdorfii', '2.tiff'),
#  ('Copaifera langsdorfii 3.tiff', 'Copaifera_langsdorfii', '3.tiff'),
#  ('Copaifera langsdorfii 4.tiff', 'Copaifera_langsdorfii', '4.tiff'),
#  ('Copaifera langsdorfii 5.tiff', 'Copaifera_langsdorfii', '5.tiff'),
#  ('Copaifera langsdorfii 6.tiff', 'Copaifera_langsdorfii', '6.tiff'),
#  ('Copaifera langsdorfii 7.tiff', 'Copaifera_langsdorfii', '7.tiff'),
#  ('Copaifera langsdorfii 8.tiff', 'Copaifera_langsdorfii', '8.tiff'),
#  ('Copaifera langsdorfii 9.tiff', 'Copaifera_langsdorfii', '9.tiff'),
#  ('Croton argyrophylloides 1.tiff', 'Croton_argyrophylloides', '1.tiff'),
#  ('Croton argyrophylloides 10.tiff', 'Croton_argyrophylloides', '10.tiff'),
#  ('Croton argyrophylloides 11.tiff', 'Croton_argyrophylloides', '11.tiff'),
#  ('Croton argyrophylloides 12.tiff', 'Croton_argyrophylloides', '12.tiff'),
#  ('Croton argyrophylloides 2.tiff', 'Croton_argyrophylloides', '2.tiff'),
#  ('Croton argyrophylloides 3.tiff', 'Croton_argyrophylloides', '3.tiff'),
#  ('Croton argyrophylloides 4.tiff', 'Croton_argyrophylloides', '4.tiff'),
#  ('Croton argyrophylloides 5.tiff', 'Croton_argyrophylloides', '5.tiff'),
#  ('Croton argyrophylloides 6.tiff', 'Croton_argyrophylloides', '6.tiff'),
#  ('Croton argyrophylloides 7.tiff', 'Croton_argyrophylloides', '7.tiff'),
#  ('Croton argyrophylloides 8.tiff', 'Croton_argyrophylloides', '8.tiff'),
#  ('Croton argyrophylloides 9.tiff', 'Croton_argyrophylloides', '9.tiff'),
#  ('Diplotropis purpurea 1.tiff', 'Diplotropis_purpurea', '1.tiff'),
#  ('Diplotropis purpurea 10.tiff', 'Diplotropis_purpurea', '10.tiff'),
#  ('Diplotropis purpurea 11.tiff', 'Diplotropis_purpurea', '11.tiff'),
#  ('Diplotropis purpurea 12.tiff', 'Diplotropis_purpurea', '12.tiff'),
#  ('Diplotropis purpurea 2.tiff', 'Diplotropis_purpurea', '2.tiff'),
#  ('Diplotropis purpurea 3.tiff', 'Diplotropis_purpurea', '3.tiff'),
#  ('Diplotropis purpurea 4.tiff', 'Diplotropis_purpurea', '4.tiff'),
#  ('Diplotropis purpurea 5.tiff', 'Diplotropis_purpurea', '5.tiff'),
#  ('Diplotropis purpurea 6.tiff', 'Diplotropis_purpurea', '6.tiff'),
#  ('Diplotropis purpurea 7.tiff', 'Diplotropis_purpurea', '7.tiff'),
#  ('Diplotropis purpurea 8.tiff', 'Diplotropis_purpurea', '8.tiff'),
#  ('Diplotropis purpurea 9.tiff', 'Diplotropis_purpurea', '9.tiff'),
#  ('Dipteryx odorata 1.tiff', 'Dipteryx_odorata', '1.tiff'),
#  ('Dipteryx odorata 10.tiff', 'Dipteryx_odorata', '10.tiff'),
#  ('Dipteryx odorata 11.tiff', 'Dipteryx_odorata', '11.tiff'),
#  ('Dipteryx odorata 12.tiff', 'Dipteryx_odorata', '12.tiff'),
#  ('Dipteryx odorata 2.tiff', 'Dipteryx_odorata', '2.tiff'),
#  ('Dipteryx odorata 3.tiff', 'Dipteryx_odorata', '3.tiff'),
#  ('Dipteryx odorata 4.tiff', 'Dipteryx_odorata', '4.tiff'),
#  ('Dipteryx odorata 5.tiff', 'Dipteryx_odorata', '5.tiff'),
#  ('Dipteryx odorata 6.tiff', 'Dipteryx_odorata', '6.tiff'),
#  ('Dipteryx odorata 7.tiff', 'Dipteryx_odorata', '7.tiff'),
#  ('Dipteryx odorata 8.tiff', 'Dipteryx_odorata', '8.tiff'),
#  ('Dipteryx odorata 9.tiff', 'Dipteryx_odorata', '9.tiff'),
#  ('Enterolobium schomburgkii 1.tiff', 'Enterolobium_schomburgkii', '1.tiff'),
#  ('Enterolobium schomburgkii 10.tiff', 'Enterolobium_schomburgkii', '10.tiff'),
#  ('Enterolobium schomburgkii 11.tiff', 'Enterolobium_schomburgkii', '11.tiff'),
#  ('Enterolobium schomburgkii 12.tiff', 'Enterolobium_schomburgkii', '12.tiff'),
#  ('Enterolobium schomburgkii 2.tiff', 'Enterolobium_schomburgkii', '2.tiff'),
#  ('Enterolobium schomburgkii 3.tiff', 'Enterolobium_schomburgkii', '3.tiff'),
#  ('Enterolobium schomburgkii 4.tiff', 'Enterolobium_schomburgkii', '4.tiff'),
#  ('Enterolobium schomburgkii 5.tiff', 'Enterolobium_schomburgkii', '5.tiff'),
#  ('Enterolobium schomburgkii 6.tiff', 'Enterolobium_schomburgkii', '6.tiff'),
#  ('Enterolobium schomburgkii 7.tiff', 'Enterolobium_schomburgkii', '7.tiff'),
#  ('Enterolobium schomburgkii 8.tiff', 'Enterolobium_schomburgkii', '8.tiff'),
#  ('Enterolobium schomburgkii 9.tiff', 'Enterolobium_schomburgkii', '9.tiff'),
#  ('Erisma uncinatum 1.tiff', 'Erisma_uncinatum', '1.tiff'),
#  ('Erisma uncinatum 10.tiff', 'Erisma_uncinatum', '10.tiff'),
#  ('Erisma uncinatum 11.tiff', 'Erisma_uncinatum', '11.tiff'),
#  ('Erisma uncinatum 12.tiff', 'Erisma_uncinatum', '12.tiff'),
#  ('Erisma uncinatum 2.tiff', 'Erisma_uncinatum', '2.tiff'),
#  ('Erisma uncinatum 3.tiff', 'Erisma_uncinatum', '3.tiff'),
#  ('Erisma uncinatum 4.tiff', 'Erisma_uncinatum', '4.tiff'),
#  ('Erisma uncinatum 5.tiff', 'Erisma_uncinatum', '5.tiff'),
#  ('Erisma uncinatum 6.tiff', 'Erisma_uncinatum', '6.tiff'),
#  ('Erisma uncinatum 7.tiff', 'Erisma_uncinatum', '7.tiff'),
#  ('Erisma uncinatum 8.tiff', 'Erisma_uncinatum', '8.tiff'),
#  ('Erisma uncinatum 9.tiff', 'Erisma_uncinatum', '9.tiff'),
#  ('Goupia glabra 1.tiff', 'Goupia_glabra', '1.tiff'),
#  ('Goupia glabra 10.tiff', 'Goupia_glabra', '10.tiff'),
#  ('Goupia glabra 11.tiff', 'Goupia_glabra', '11.tiff'),
#  ('Goupia glabra 12.tiff', 'Goupia_glabra', '12.tiff'),
#  ('Goupia glabra 2.tiff', 'Goupia_glabra', '2.tiff'),
#  ('Goupia glabra 3.tiff', 'Goupia_glabra', '3.tiff'),
#  ('Goupia glabra 4.tiff', 'Goupia_glabra', '4.tiff'),
#  ('Goupia glabra 5.tiff', 'Goupia_glabra', '5.tiff'),
#  ('Goupia glabra 6.tiff', 'Goupia_glabra', '6.tiff'),
#  ('Goupia glabra 7.tiff', 'Goupia_glabra', '7.tiff'),
#  ('Goupia glabra 8.tiff', 'Goupia_glabra', '8.tiff'),
#  ('Goupia glabra 9.tiff', 'Goupia_glabra', '9.tiff'),
#  ('Hieronyma laxiflora 1.tiff', 'Hieronyma_laxiflora', '1.tiff'),
#  ('Hieronyma laxiflora 10.tiff', 'Hieronyma_laxiflora', '10.tiff'),
#  ('Hieronyma laxiflora 11.tiff', 'Hieronyma_laxiflora', '11.tiff'),
#  ('Hieronyma laxiflora 12.tiff', 'Hieronyma_laxiflora', '12.tiff'),
#  ('Hieronyma laxiflora 2.tiff', 'Hieronyma_laxiflora', '2.tiff'),
#  ('Hieronyma laxiflora 3.tiff', 'Hieronyma_laxiflora', '3.tiff'),
#  ('Hieronyma laxiflora 4.tiff', 'Hieronyma_laxiflora', '4.tiff'),
#  ('Hieronyma laxiflora 5.tiff', 'Hieronyma_laxiflora', '5.tiff'),
#  ('Hieronyma laxiflora 6.tiff', 'Hieronyma_laxiflora', '6.tiff'),
#  ('Hieronyma laxiflora 7.tiff', 'Hieronyma_laxiflora', '7.tiff'),
#  ('Hieronyma laxiflora 8.tiff', 'Hieronyma_laxiflora', '8.tiff'),
#  ('Hieronyma laxiflora 9.tiff', 'Hieronyma_laxiflora', '9.tiff'),
#  ('Hymenaea courbaril 1.tiff', 'Hymenaea_courbaril', '1.tiff'),
#  ('Hymenaea courbaril 10.tiff', 'Hymenaea_courbaril', '10.tiff'),
#  ('Hymenaea courbaril 11.tiff', 'Hymenaea_courbaril', '11.tiff'),
#  ('Hymenaea courbaril 12.tiff', 'Hymenaea_courbaril', '12.tiff'),
#  ('Hymenaea courbaril 2.tiff', 'Hymenaea_courbaril', '2.tiff'),
#  ('Hymenaea courbaril 3.tiff', 'Hymenaea_courbaril', '3.tiff'),
#  ('Hymenaea courbaril 4.tiff', 'Hymenaea_courbaril', '4.tiff'),
#  ('Hymenaea courbaril 5.tiff', 'Hymenaea_courbaril', '5.tiff'),
#  ('Hymenaea courbaril 6.tiff', 'Hymenaea_courbaril', '6.tiff'),
#  ('Hymenaea courbaril 7.tiff', 'Hymenaea_courbaril', '7.tiff'),
#  ('Hymenaea courbaril 8.tiff', 'Hymenaea_courbaril', '8.tiff'),
#  ('Hymenaea courbaril 9.tiff', 'Hymenaea_courbaril', '9.tiff'),
#  ('Hymenolobium petraeum 1.tiff', 'Hymenolobium_petraeum', '1.tiff'),
#  ('Hymenolobium petraeum 10.tiff', 'Hymenolobium_petraeum', '10.tiff'),
#  ('Hymenolobium petraeum 11.tiff', 'Hymenolobium_petraeum', '11.tiff'),
#  ('Hymenolobium petraeum 12.tiff', 'Hymenolobium_petraeum', '12.tiff'),
#  ('Hymenolobium petraeum 2.tiff', 'Hymenolobium_petraeum', '2.tiff'),
#  ('Hymenolobium petraeum 3.tiff', 'Hymenolobium_petraeum', '3.tiff'),
#  ('Hymenolobium petraeum 4.tiff', 'Hymenolobium_petraeum', '4.tiff'),
#  ('Hymenolobium petraeum 5.tiff', 'Hymenolobium_petraeum', '5.tiff'),
#  ('Hymenolobium petraeum 6.tiff', 'Hymenolobium_petraeum', '6.tiff'),
#  ('Hymenolobium petraeum 7.tiff', 'Hymenolobium_petraeum', '7.tiff'),
#  ('Hymenolobium petraeum 8.tiff', 'Hymenolobium_petraeum', '8.tiff'),
#  ('Hymenolobium petraeum 9.tiff', 'Hymenolobium_petraeum', '9.tiff'),
#  ('Jacaranda copaia 1.tiff', 'Jacaranda_copaia', '1.tiff'),
#  ('Jacaranda copaia 10.tiff', 'Jacaranda_copaia', '10.tiff'),
#  ('Jacaranda copaia 11.tiff', 'Jacaranda_copaia', '11.tiff'),
#  ('Jacaranda copaia 12.tiff', 'Jacaranda_copaia', '12.tiff'),
#  ('Jacaranda copaia 2.tiff', 'Jacaranda_copaia', '2.tiff'),
#  ('Jacaranda copaia 3.tiff', 'Jacaranda_copaia', '3.tiff'),
#  ('Jacaranda copaia 4.tiff', 'Jacaranda_copaia', '4.tiff'),
#  ('Jacaranda copaia 5.tiff', 'Jacaranda_copaia', '5.tiff'),
#  ('Jacaranda copaia 6.tiff', 'Jacaranda_copaia', '6.tiff'),
#  ('Jacaranda copaia 7.tiff', 'Jacaranda_copaia', '7.tiff'),
#  ('Jacaranda copaia 8.tiff', 'Jacaranda_copaia', '8.tiff'),
#  ('Jacaranda copaia 9.tiff', 'Jacaranda_copaia', '9.tiff'),
#  ('Jatropha mutabilis 1.tiff', 'Jatropha_mutabilis', '1.tiff'),
#  ('Jatropha mutabilis 10.tiff', 'Jatropha_mutabilis', '10.tiff'),
#  ('Jatropha mutabilis 11.tiff', 'Jatropha_mutabilis', '11.tiff'),
#  ('Jatropha mutabilis 12.tiff', 'Jatropha_mutabilis', '12.tiff'),
#  ('Jatropha mutabilis 2.tiff', 'Jatropha_mutabilis', '2.tiff'),
#  ('Jatropha mutabilis 3.tiff', 'Jatropha_mutabilis', '3.tiff'),
#  ('Jatropha mutabilis 4.tiff', 'Jatropha_mutabilis', '4.tiff'),
#  ('Jatropha mutabilis 5.tiff', 'Jatropha_mutabilis', '5.tiff'),
#  ('Jatropha mutabilis 6.tiff', 'Jatropha_mutabilis', '6.tiff'),
#  ('Jatropha mutabilis 7.tiff', 'Jatropha_mutabilis', '7.tiff'),
#  ('Jatropha mutabilis 8.tiff', 'Jatropha_mutabilis', '8.tiff'),
#  ('Jatropha mutabilis 9.tiff', 'Jatropha_mutabilis', '9.tiff'),
#  ('Licaria cannela 1.tiff', 'Licaria_cannela', '1.tiff'),
#  ('Licaria cannela 10.tiff', 'Licaria_cannela', '10.tiff'),
#  ('Licaria cannela 11.tiff', 'Licaria_cannela', '11.tiff'),
#  ('Licaria cannela 12.tiff', 'Licaria_cannela', '12.tiff'),
#  ('Licaria cannela 2.tiff', 'Licaria_cannela', '2.tiff'),
#  ('Licaria cannela 3.tiff', 'Licaria_cannela', '3.tiff'),
#  ('Licaria cannela 4.tiff', 'Licaria_cannela', '4.tiff'),
#  ('Licaria cannela 5.tiff', 'Licaria_cannela', '5.tiff'),
#  ('Licaria cannela 6.tiff', 'Licaria_cannela', '6.tiff'),
#  ('Licaria cannela 7.tiff', 'Licaria_cannela', '7.tiff'),
#  ('Licaria cannela 8.tiff', 'Licaria_cannela', '8.tiff'),
#  ('Licaria cannela 9.tiff', 'Licaria_cannela', '9.tiff'),
#  ('Luitzelburgia auriculata 1.tiff', 'Luitzelburgia_auriculata', '1.tiff'),
#  ('Luitzelburgia auriculata 10.tiff', 'Luitzelburgia_auriculata', '10.tiff'),
#  ('Luitzelburgia auriculata 11.tiff', 'Luitzelburgia_auriculata', '11.tiff'),
#  ('Luitzelburgia auriculata 12.tiff', 'Luitzelburgia_auriculata', '12.tiff'),
#  ('Luitzelburgia auriculata 2.tiff', 'Luitzelburgia_auriculata', '2.tiff'),
#  ('Luitzelburgia auriculata 3.tiff', 'Luitzelburgia_auriculata', '3.tiff'),
#  ('Luitzelburgia auriculata 4.tiff', 'Luitzelburgia_auriculata', '4.tiff'),
#  ('Luitzelburgia auriculata 5.tiff', 'Luitzelburgia_auriculata', '5.tiff'),
#  ('Luitzelburgia auriculata 6.tiff', 'Luitzelburgia_auriculata', '6.tiff'),
#  ('Luitzelburgia auriculata 7.tiff', 'Luitzelburgia_auriculata', '7.tiff'),
#  ('Luitzelburgia auriculata 8.tiff', 'Luitzelburgia_auriculata', '8.tiff'),
#  ('Luitzelburgia auriculata 9.tiff', 'Luitzelburgia_auriculata', '9.tiff'),
#  ('Mezilaurus itauba 1.tiff', 'Mezilaurus_itauba', '1.tiff'),
#  ('Mezilaurus itauba 10.tiff', 'Mezilaurus_itauba', '10.tiff'),
#  ('Mezilaurus itauba 11.tiff', 'Mezilaurus_itauba', '11.tiff'),
#  ('Mezilaurus itauba 12.tiff', 'Mezilaurus_itauba', '12.tiff'),
#  ('Mezilaurus itauba 2.tiff', 'Mezilaurus_itauba', '2.tiff'),
#  ('Mezilaurus itauba 3.tiff', 'Mezilaurus_itauba', '3.tiff'),
#  ('Mezilaurus itauba 4.tiff', 'Mezilaurus_itauba', '4.tiff'),
#  ('Mezilaurus itauba 5.tiff', 'Mezilaurus_itauba', '5.tiff'),
#  ('Mezilaurus itauba 6.tiff', 'Mezilaurus_itauba', '6.tiff'),
#  ('Mezilaurus itauba 7.tiff', 'Mezilaurus_itauba', '7.tiff'),
#  ('Mezilaurus itauba 8.tiff', 'Mezilaurus_itauba', '8.tiff'),
#  ('Mezilaurus itauba 9.tiff', 'Mezilaurus_itauba', '9.tiff'),
#  ('Mimosa scabrella 1.tiff', 'Mimosa_scabrella', '1.tiff'),
#  ('Mimosa scabrella 10.tiff', 'Mimosa_scabrella', '10.tiff'),
#  ('Mimosa scabrella 11.tiff', 'Mimosa_scabrella', '11.tiff'),
#  ('Mimosa scabrella 12.tiff', 'Mimosa_scabrella', '12.tiff'),
#  ('Mimosa scabrella 2.tiff', 'Mimosa_scabrella', '2.tiff'),
#  ('Mimosa scabrella 3.tiff', 'Mimosa_scabrella', '3.tiff'),
#  ('Mimosa scabrella 4.tiff', 'Mimosa_scabrella', '4.tiff'),
#  ('Mimosa scabrella 5.tiff', 'Mimosa_scabrella', '5.tiff'),
#  ('Mimosa scabrella 6.tiff', 'Mimosa_scabrella', '6.tiff'),
#  ('Mimosa scabrella 7.tiff', 'Mimosa_scabrella', '7.tiff'),
#  ('Mimosa scabrella 8.tiff', 'Mimosa_scabrella', '8.tiff'),
#  ('Mimosa scabrella 9.tiff', 'Mimosa_scabrella', '9.tiff'),
#  ('Ocotea leucoxylon 1.tiff', 'Ocotea_leucoxylon', '1.tiff'),
#  ('Ocotea leucoxylon 10.tiff', 'Ocotea_leucoxylon', '10.tiff'),
#  ('Ocotea leucoxylon 11.tiff', 'Ocotea_leucoxylon', '11.tiff'),
#  ('Ocotea leucoxylon 12.tiff', 'Ocotea_leucoxylon', '12.tiff'),
#  ('Ocotea leucoxylon 2.tiff', 'Ocotea_leucoxylon', '2.tiff'),
#  ('Ocotea leucoxylon 3.tiff', 'Ocotea_leucoxylon', '3.tiff'),
#  ('Ocotea leucoxylon 4.tiff', 'Ocotea_leucoxylon', '4.tiff'),
#  ('Ocotea leucoxylon 5.tiff', 'Ocotea_leucoxylon', '5.tiff'),
#  ('Ocotea leucoxylon 6.tiff', 'Ocotea_leucoxylon', '6.tiff'),
#  ('Ocotea leucoxylon 7.tiff', 'Ocotea_leucoxylon', '7.tiff'),
#  ('Ocotea leucoxylon 8.tiff', 'Ocotea_leucoxylon', '8.tiff'),
#  ('Ocotea leucoxylon 9.tiff', 'Ocotea_leucoxylon', '9.tiff'),
#  ('Ocotea odorifera 1.tiff', 'Ocotea_odorifera', '1.tiff'),
#  ('Ocotea odorifera 10.tiff', 'Ocotea_odorifera', '10.tiff'),
#  ('Ocotea odorifera 11.tiff', 'Ocotea_odorifera', '11.tiff'),
#  ('Ocotea odorifera 12.tiff', 'Ocotea_odorifera', '12.tiff'),
#  ('Ocotea odorifera 2.tiff', 'Ocotea_odorifera', '2.tiff'),
#  ('Ocotea odorifera 3.tiff', 'Ocotea_odorifera', '3.tiff'),
#  ('Ocotea odorifera 4.tiff', 'Ocotea_odorifera', '4.tiff'),
#  ('Ocotea odorifera 5.tiff', 'Ocotea_odorifera', '5.tiff'),
#  ('Ocotea odorifera 6.tiff', 'Ocotea_odorifera', '6.tiff'),
#  ('Ocotea odorifera 7.tiff', 'Ocotea_odorifera', '7.tiff'),
#  ('Ocotea odorifera 8.tiff', 'Ocotea_odorifera', '8.tiff'),
#  ('Ocotea odorifera 9.tiff', 'Ocotea_odorifera', '9.tiff'),
#  ('Ocotea porosa 1.tiff', 'Ocotea_porosa', '1.tiff'),
#  ('Ocotea porosa 10.tiff', 'Ocotea_porosa', '10.tiff'),
#  ('Ocotea porosa 11.tiff', 'Ocotea_porosa', '11.tiff'),
#  ('Ocotea porosa 12.tiff', 'Ocotea_porosa', '12.tiff'),
#  ('Ocotea porosa 2.tiff', 'Ocotea_porosa', '2.tiff'),
#  ('Ocotea porosa 3.tiff', 'Ocotea_porosa', '3.tiff'),
#  ('Ocotea porosa 4.tiff', 'Ocotea_porosa', '4.tiff'),
#  ('Ocotea porosa 5.tiff', 'Ocotea_porosa', '5.tiff'),
#  ('Ocotea porosa 6.tiff', 'Ocotea_porosa', '6.tiff'),
#  ('Ocotea porosa 7.tiff', 'Ocotea_porosa', '7.tiff'),
#  ('Ocotea porosa 8.tiff', 'Ocotea_porosa', '8.tiff'),
#  ('Ocotea porosa 9.tiff', 'Ocotea_porosa', '9.tiff'),
#  ('Parkia pendula 1.tiff', 'Parkia_pendula', '1.tiff'),
#  ('Parkia pendula 10.tiff', 'Parkia_pendula', '10.tiff'),
#  ('Parkia pendula 11.tiff', 'Parkia_pendula', '11.tiff'),
#  ('Parkia pendula 12.tiff', 'Parkia_pendula', '12.tiff'),
#  ('Parkia pendula 2.tiff', 'Parkia_pendula', '2.tiff'),
#  ('Parkia pendula 3.tiff', 'Parkia_pendula', '3.tiff'),
#  ('Parkia pendula 4.tiff', 'Parkia_pendula', '4.tiff'),
#  ('Parkia pendula 5.tiff', 'Parkia_pendula', '5.tiff'),
#  ('Parkia pendula 6.tiff', 'Parkia_pendula', '6.tiff'),
#  ('Parkia pendula 7.tiff', 'Parkia_pendula', '7.tiff'),
#  ('Parkia pendula 8.tiff', 'Parkia_pendula', '8.tiff'),
#  ('Parkia pendula 9.tiff', 'Parkia_pendula', '9.tiff'),
#  ('Pera glabrata 1.tiff', 'Pera_glabrata', '1.tiff'),
#  ('Pera glabrata 10.tiff', 'Pera_glabrata', '10.tiff'),
#  ('Pera glabrata 11.tiff', 'Pera_glabrata', '11.tiff'),
#  ('Pera glabrata 12.tiff', 'Pera_glabrata', '12.tiff'),
#  ('Pera glabrata 2.tiff', 'Pera_glabrata', '2.tiff'),
#  ('Pera glabrata 3.tiff', 'Pera_glabrata', '3.tiff'),
#  ('Pera glabrata 4.tiff', 'Pera_glabrata', '4.tiff'),
#  ('Pera glabrata 5.tiff', 'Pera_glabrata', '5.tiff'),
#  ('Pera glabrata 6.tiff', 'Pera_glabrata', '6.tiff'),
#  ('Pera glabrata 7.tiff', 'Pera_glabrata', '7.tiff'),
#  ('Pera glabrata 8.tiff', 'Pera_glabrata', '8.tiff'),
#  ('Pera glabrata 9.tiff', 'Pera_glabrata', '9.tiff'),
#  ('Piptadenia communis 1.tiff', 'Piptadenia_communis', '1.tiff'),
#  ('Piptadenia communis 10.tiff', 'Piptadenia_communis', '10.tiff'),
#  ('Piptadenia communis 11.tiff', 'Piptadenia_communis', '11.tiff'),
#  ('Piptadenia communis 12.tiff', 'Piptadenia_communis', '12.tiff'),
#  ('Piptadenia communis 2.tiff', 'Piptadenia_communis', '2.tiff'),
#  ('Piptadenia communis 3.tiff', 'Piptadenia_communis', '3.tiff'),
#  ('Piptadenia communis 4.tiff', 'Piptadenia_communis', '4.tiff'),
#  ('Piptadenia communis 5.tiff', 'Piptadenia_communis', '5.tiff'),
#  ('Piptadenia communis 6.tiff', 'Piptadenia_communis', '6.tiff'),
#  ('Piptadenia communis 7.tiff', 'Piptadenia_communis', '7.tiff'),
#  ('Piptadenia communis 8.tiff', 'Piptadenia_communis', '8.tiff'),
#  ('Piptadenia communis 9.tiff', 'Piptadenia_communis', '9.tiff'),
#  ('Poeppigia procera 1.tiff', 'Poeppigia_procera', '1.tiff'),
#  ('Poeppigia procera 10.tiff', 'Poeppigia_procera', '10.tiff'),
#  ('Poeppigia procera 11.tiff', 'Poeppigia_procera', '11.tiff'),
#  ('Poeppigia procera 12.tiff', 'Poeppigia_procera', '12.tiff'),
#  ('Poeppigia procera 2.tiff', 'Poeppigia_procera', '2.tiff'),
#  ('Poeppigia procera 3.tiff', 'Poeppigia_procera', '3.tiff'),
#  ('Poeppigia procera 4.tiff', 'Poeppigia_procera', '4.tiff'),
#  ('Poeppigia procera 5.tiff', 'Poeppigia_procera', '5.tiff'),
#  ('Poeppigia procera 6.tiff', 'Poeppigia_procera', '6.tiff'),
#  ('Poeppigia procera 7.tiff', 'Poeppigia_procera', '7.tiff'),
#  ('Poeppigia procera 8.tiff', 'Poeppigia_procera', '8.tiff'),
#  ('Poeppigia procera 9.tiff', 'Poeppigia_procera', '9.tiff'),
#  ('Poincianella bracteosa 1.tiff', 'Poincianella_bracteosa', '1.tiff'),
#  ('Poincianella bracteosa 10.tiff', 'Poincianella_bracteosa', '10.tiff'),
#  ('Poincianella bracteosa 11.tiff', 'Poincianella_bracteosa', '11.tiff'),
#  ('Poincianella bracteosa 12.tiff', 'Poincianella_bracteosa', '12.tiff'),
#  ('Poincianella bracteosa 2.tiff', 'Poincianella_bracteosa', '2.tiff'),
#  ('Poincianella bracteosa 3.tiff', 'Poincianella_bracteosa', '3.tiff'),
#  ('Poincianella bracteosa 4.tiff', 'Poincianella_bracteosa', '4.tiff'),
#  ('Poincianella bracteosa 5.tiff', 'Poincianella_bracteosa', '5.tiff'),
#  ('Poincianella bracteosa 6.tiff', 'Poincianella_bracteosa', '6.tiff'),
#  ('Poincianella bracteosa 7.tiff', 'Poincianella_bracteosa', '7.tiff'),
#  ('Poincianella bracteosa 8.tiff', 'Poincianella_bracteosa', '8.tiff'),
#  ('Poincianella bracteosa 9.tiff', 'Poincianella_bracteosa', '9.tiff'),
#  ('Qualea paraensis 1.tiff', 'Qualea_paraensis', '1.tiff'),
#  ('Qualea paraensis 10.tiff', 'Qualea_paraensis', '10.tiff'),
#  ('Qualea paraensis 11.tiff', 'Qualea_paraensis', '11.tiff'),
#  ('Qualea paraensis 12.tiff', 'Qualea_paraensis', '12.tiff'),
#  ('Qualea paraensis 2.tiff', 'Qualea_paraensis', '2.tiff'),
#  ('Qualea paraensis 3.tiff', 'Qualea_paraensis', '3.tiff'),
#  ('Qualea paraensis 4.tiff', 'Qualea_paraensis', '4.tiff'),
#  ('Qualea paraensis 5.tiff', 'Qualea_paraensis', '5.tiff'),
#  ('Qualea paraensis 6.tiff', 'Qualea_paraensis', '6.tiff'),
#  ('Qualea paraensis 7.tiff', 'Qualea_paraensis', '7.tiff'),
#  ('Qualea paraensis 8.tiff', 'Qualea_paraensis', '8.tiff'),
#  ('Qualea paraensis 9.tiff', 'Qualea_paraensis', '9.tiff'),
#  ('Sapium glandulatum 1.tiff', 'Sapium_glandulatum', '1.tiff'),
#  ('Sapium glandulatum 10.tiff', 'Sapium_glandulatum', '10.tiff'),
#  ('Sapium glandulatum 11.tiff', 'Sapium_glandulatum', '11.tiff'),
#  ('Sapium glandulatum 12.tiff', 'Sapium_glandulatum', '12.tiff'),
#  ('Sapium glandulatum 2.tiff', 'Sapium_glandulatum', '2.tiff'),
#  ('Sapium glandulatum 3.tiff', 'Sapium_glandulatum', '3.tiff'),
#  ('Sapium glandulatum 4.tiff', 'Sapium_glandulatum', '4.tiff'),
#  ('Sapium glandulatum 5.tiff', 'Sapium_glandulatum', '5.tiff'),
#  ('Sapium glandulatum 6.tiff', 'Sapium_glandulatum', '6.tiff'),
#  ('Sapium glandulatum 7.tiff', 'Sapium_glandulatum', '7.tiff'),
#  ('Sapium glandulatum 8.tiff', 'Sapium_glandulatum', '8.tiff'),
#  ('Sapium glandulatum 9.tiff', 'Sapium_glandulatum', '9.tiff'),
#  ('Schefflera morototoni 1.tiff', 'Schefflera_morototoni', '1.tiff'),
#  ('Schefflera morototoni 10.tiff', 'Schefflera_morototoni', '10.tiff'),
#  ('Schefflera morototoni 11.tiff', 'Schefflera_morototoni', '11.tiff'),
#  ('Schefflera morototoni 12.tiff', 'Schefflera_morototoni', '12.tiff'),
#  ('Schefflera morototoni 2.tiff', 'Schefflera_morototoni', '2.tiff'),
#  ('Schefflera morototoni 3.tiff', 'Schefflera_morototoni', '3.tiff'),
#  ('Schefflera morototoni 4.tiff', 'Schefflera_morototoni', '4.tiff'),
#  ('Schefflera morototoni 5.tiff', 'Schefflera_morototoni', '5.tiff'),
#  ('Schefflera morototoni 6.tiff', 'Schefflera_morototoni', '6.tiff'),
#  ('Schefflera morototoni 7.tiff', 'Schefflera_morototoni', '7.tiff'),
#  ('Schefflera morototoni 8.tiff', 'Schefflera_morototoni', '8.tiff'),
#  ('Schefflera morototoni 9.tiff', 'Schefflera_morototoni', '9.tiff'),
#  ('Sclerolobium paniculatum 1.tiff', 'Sclerolobium_paniculatum', '1.tiff'),
#  ('Sclerolobium paniculatum 10.tiff', 'Sclerolobium_paniculatum', '10.tiff'),
#  ('Sclerolobium paniculatum 11.tiff', 'Sclerolobium_paniculatum', '11.tiff'),
#  ('Sclerolobium paniculatum 12.tiff', 'Sclerolobium_paniculatum', '12.tiff'),
#  ('Sclerolobium paniculatum 2.tiff', 'Sclerolobium_paniculatum', '2.tiff'),
#  ('Sclerolobium paniculatum 3.tiff', 'Sclerolobium_paniculatum', '3.tiff'),
#  ('Sclerolobium paniculatum 4.tiff', 'Sclerolobium_paniculatum', '4.tiff'),
#  ('Sclerolobium paniculatum 5.tiff', 'Sclerolobium_paniculatum', '5.tiff'),
#  ('Sclerolobium paniculatum 6.tiff', 'Sclerolobium_paniculatum', '6.tiff'),
#  ('Sclerolobium paniculatum 7.tiff', 'Sclerolobium_paniculatum', '7.tiff'),
#  ('Sclerolobium paniculatum 8.tiff', 'Sclerolobium_paniculatum', '8.tiff'),
#  ('Sclerolobium paniculatum 9.tiff', 'Sclerolobium_paniculatum', '9.tiff'),
#  ('Tabebuia alba 1.tiff', 'Tabebuia_alba', '1.tiff'),
#  ('Tabebuia alba 10.tiff', 'Tabebuia_alba', '10.tiff'),
#  ('Tabebuia alba 11.tiff', 'Tabebuia_alba', '11.tiff'),
#  ('Tabebuia alba 12.tiff', 'Tabebuia_alba', '12.tiff'),
#  ('Tabebuia alba 2.tiff', 'Tabebuia_alba', '2.tiff'),
#  ('Tabebuia alba 3.tiff', 'Tabebuia_alba', '3.tiff'),
#  ('Tabebuia alba 4.tiff', 'Tabebuia_alba', '4.tiff'),
#  ('Tabebuia alba 5.tiff', 'Tabebuia_alba', '5.tiff'),
#  ('Tabebuia alba 6.tiff', 'Tabebuia_alba', '6.tiff'),
#  ('Tabebuia alba 7.tiff', 'Tabebuia_alba', '7.tiff'),
#  ('Tabebuia alba 8.tiff', 'Tabebuia_alba', '8.tiff'),
#  ('Tabebuia alba 9.tiff', 'Tabebuia_alba', '9.tiff'),
#  ('Trattinnickia burseraefolia 1.tiff',
#   'Trattinnickia_burseraefolia',
#   '1.tiff'),
#  ('Trattinnickia burseraefolia 10.tiff',
#   'Trattinnickia_burseraefolia',
#   '10.tiff'),
#  ('Trattinnickia burseraefolia 11.tiff',
#   'Trattinnickia_burseraefolia',
#   '11.tiff'),
#  ('Trattinnickia burseraefolia 12.tiff',
#   'Trattinnickia_burseraefolia',
#   '12.tiff'),
#  ('Trattinnickia burseraefolia 2.tiff',
#   'Trattinnickia_burseraefolia',
#   '2.tiff'),
#  ('Trattinnickia burseraefolia 3.tiff',
#   'Trattinnickia_burseraefolia',
#   '3.tiff'),
#  ('Trattinnickia burseraefolia 4.tiff',
#   'Trattinnickia_burseraefolia',
#   '4.tiff'),
#  ('Trattinnickia burseraefolia 5.tiff',
#   'Trattinnickia_burseraefolia',
#   '5.tiff'),
#  ('Trattinnickia burseraefolia 6.tiff',
#   'Trattinnickia_burseraefolia',
#   '6.tiff'),
#  ('Trattinnickia burseraefolia 7.tiff',
#   'Trattinnickia_burseraefolia',
#   '7.tiff'),
#  ('Trattinnickia burseraefolia 8.tiff',
#   'Trattinnickia_burseraefolia',
#   '8.tiff'),
#  ('Trattinnickia burseraefolia 9.tiff',
#   'Trattinnickia_burseraefolia',
#   '9.tiff'),
#  ('Vatairea guianensis 1.tiff', 'Vatairea_guianensis', '1.tiff'),
#  ('Vatairea guianensis 10.tiff', 'Vatairea_guianensis', '10.tiff'),
#  ('Vatairea guianensis 11.tiff', 'Vatairea_guianensis', '11.tiff'),
#  ('Vatairea guianensis 12.tiff', 'Vatairea_guianensis', '12.tiff'),
#  ('Vatairea guianensis 2.tiff', 'Vatairea_guianensis', '2.tiff'),
#  ('Vatairea guianensis 3.tiff', 'Vatairea_guianensis', '3.tiff'),
#  ('Vatairea guianensis 4.tiff', 'Vatairea_guianensis', '4.tiff'),
#  ('Vatairea guianensis 5.tiff', 'Vatairea_guianensis', '5.tiff'),
#  ('Vatairea guianensis 6.tiff', 'Vatairea_guianensis', '6.tiff'),
#  ('Vatairea guianensis 7.tiff', 'Vatairea_guianensis', '7.tiff'),
#  ('Vatairea guianensis 8.tiff', 'Vatairea_guianensis', '8.tiff'),
#  ('Vatairea guianensis 9.tiff', 'Vatairea_guianensis', '9.tiff'),
#  ('Vatairea paraensis 1.tiff', 'Vatairea_paraensis', '1.tiff'),
#  ('Vatairea paraensis 10.tiff', 'Vatairea_paraensis', '10.tiff'),
#  ('Vatairea paraensis 11.tiff', 'Vatairea_paraensis', '11.tiff'),
#  ('Vatairea paraensis 12.tiff', 'Vatairea_paraensis', '12.tiff'),
#  ('Vatairea paraensis 2.tiff', 'Vatairea_paraensis', '2.tiff'),
#  ('Vatairea paraensis 3.tiff', 'Vatairea_paraensis', '3.tiff'),
#  ('Vatairea paraensis 4.tiff', 'Vatairea_paraensis', '4.tiff'),
#  ('Vatairea paraensis 5.tiff', 'Vatairea_paraensis', '5.tiff'),
#  ('Vatairea paraensis 6.tiff', 'Vatairea_paraensis', '6.tiff'),
#  ('Vatairea paraensis 7.tiff', 'Vatairea_paraensis', '7.tiff'),
#  ('Vatairea paraensis 8.tiff', 'Vatairea_paraensis', '8.tiff'),
#  ('Vatairea paraensis 9.tiff', 'Vatairea_paraensis', '9.tiff'),
#  ('Vochysia densiflora 1.tiff', 'Vochysia_densiflora', '1.tiff'),
#  ('Vochysia densiflora 10.tiff', 'Vochysia_densiflora', '10.tiff'),
#  ('Vochysia densiflora 11.tiff', 'Vochysia_densiflora', '11.tiff'),
#  ('Vochysia densiflora 12.tiff', 'Vochysia_densiflora', '12.tiff'),
#  ('Vochysia densiflora 2.tiff', 'Vochysia_densiflora', '2.tiff'),
#  ('Vochysia densiflora 3.tiff', 'Vochysia_densiflora', '3.tiff'),
#  ('Vochysia densiflora 4.tiff', 'Vochysia_densiflora', '4.tiff'),
#  ('Vochysia densiflora 5.tiff', 'Vochysia_densiflora', '5.tiff'),
#  ('Vochysia densiflora 6.tiff', 'Vochysia_densiflora', '6.tiff'),
#  ('Vochysia densiflora 7.tiff', 'Vochysia_densiflora', '7.tiff'),
#  ('Vochysia densiflora 8.tiff', 'Vochysia_densiflora', '8.tiff'),
#  ('Vochysia densiflora 9.tiff', 'Vochysia_densiflora', '9.tiff'),
#  ('Vochysia maxima 1.tiff', 'Vochysia_maxima', '1.tiff'),
#  ('Vochysia maxima 10.tiff', 'Vochysia_maxima', '10.tiff'),
#  ('Vochysia maxima 11.tiff', 'Vochysia_maxima', '11.tiff'),
#  ('Vochysia maxima 12.tiff', 'Vochysia_maxima', '12.tiff'),
#  ('Vochysia maxima 2.tiff', 'Vochysia_maxima', '2.tiff'),
#  ('Vochysia maxima 3.tiff', 'Vochysia_maxima', '3.tiff'),
#  ('Vochysia maxima 4.tiff', 'Vochysia_maxima', '4.tiff'),
#  ('Vochysia maxima 5.tiff', 'Vochysia_maxima', '5.tiff'),
#  ('Vochysia maxima 6.tiff', 'Vochysia_maxima', '6.tiff'),
#  ('Vochysia maxima 7.tiff', 'Vochysia_maxima', '7.tiff'),
#  ('Vochysia maxima 8.tiff', 'Vochysia_maxima', '8.tiff'),
#  ('Vochysia maxima 9.tiff', 'Vochysia_maxima', '9.tiff')]

# %%
# ?os.mkdir
